# %%
import torch.nn as nn

# %%
class UnetDownBlock:
    def __init__(self, in_channels, out_channels, skip_connection)
        

class UnetUpBlock:
    def __init__(self, in_channels, out_channels, skip_connection)
